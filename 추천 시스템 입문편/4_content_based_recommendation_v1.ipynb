# %% [markdown]
# # [추천 시스템 입문편] Content-Based Recommendation 1

# %% [markdown]
# ## 데이터 전처리

# %%
# 필요한 패키지 설치
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 읽어오기
movies = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/추천 시스템 입문편/data/ml-latest-small/movies.csv')
ratings = pd.read_pickle('/content/drive/MyDrive/Colab Notebooks/추천 시스템 입문편/data/ml-latest-small/ratings_update.p')
genres = pd.read_pickle('/content/drive/MyDrive/Colab Notebooks/추천 시스템 입문편/data/ml-latest-small/genres.p')

# %%
ratings.sample()
# Out:
#        userId  movieId  rating           timestamp
# 41832     285     1193     5.0 2015-12-26 17:32:33

# %%
genres.sample()
# Out:
#          (no genres listed)  Action  Adventure  Animation  Children  Comedy  \
# movieId
# 6390                      0       0          0          0         0       0
#
#          Crime  Documentary  Drama  Fantasy  Film-Noir  Horror  IMAX  Musical  \
# movieId
# 6390         0            0      0        0          0       0     0        1
#
#          Mystery  Romance  Sci-Fi  Thriller  War  Western
# movieId
# 6390           0        0       0         0    0        0

# %%
# ratings 테이블에 genres 데이터를 이너 조인으로 붙이기
# ratings의 movieId와 genres의 index(movieId)를 기준으로 조인
ratings = ratings.merge(genres, left_on='movieId', right_index=True)
ratings.sample()
# Out:
#        userId  movieId  rating           timestamp  (no genres listed)  \
# 34662     232    61250     2.5 2010-08-30 01:59:28                   0
#
#        Action  Adventure  Animation  Children  Comedy  ...  Film-Noir  Horror  \
# 34662       0          0          0         0       1  ...          0       0
#
#        IMAX  Musical  Mystery  Romance  Sci-Fi  Thriller  War  Western
# 34662     0        0        0        0       0         0    0        0
#
# [1 rows x 24 columns]

# %%
# 0 값을 NaN으로 바꿔주기
ratings = ratings.replace(0, np.nan)
ratings.sample()
# Out:
#        userId  movieId  rating           timestamp  (no genres listed)  \
# 63239     414     2804     4.0 2000-06-20 15:58:13                 NaN
#
#        Action  Adventure  Animation  Children  Comedy  ...  Film-Noir  Horror  \
# 63239     NaN        NaN        NaN       1.0     1.0  ...        NaN     NaN
#
#        IMAX  Musical  Mystery  Romance  Sci-Fi  Thriller  War  Western
# 63239   NaN      NaN      NaN      NaN     NaN       NaN  NaN      NaN
#
# [1 rows x 24 columns]

# %%
# 모델을 훈련하는 데이터와 성능을 테스트하는 데이터로 나눠주기
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(ratings, random_state=42, test_size=0.1)

# %%
print(train.shape)
print(test.shape)
# Out:
# (90755, 24)
# (10084, 24)

# %%
# 아이템 프로필 만들기 (장르 테이블과 동일)
# 어떤 아이템이 어떤 장르를 가지고 있는지를 보여줌
# 해리포터의 장르
genres.loc[4896]
# Out:
# (no genres listed)    0
# Action                0
# Adventure             1
# Animation             0
# Children              1
# Comedy                0
# Crime                 0
# Documentary           0
# Drama                 0
# Fantasy               1
# Film-Noir             0
# Horror                0
# IMAX                  0
# Musical               0
# Mystery               0
# Romance               0
# Sci-Fi                0
# Thriller              0
# War                   0
# Western               0
# Name: 4896, dtype: int64

# %% [markdown]
# ## 유저 프로필 만들기

# %%
# 장르 이름 가져오기
genre_cols = genres.columns
genre_cols
# Out:
# Index(['(no genres listed)', 'Action', 'Adventure', 'Animation', 'Children',
#        'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy', 'Film-Noir',
#        'Horror', 'IMAX', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller',
#        'War', 'Western'],
#       dtype='object')

# %%
# 각 영화에 대해서 장르에 몇 점을 줬는지 곱하기 연산
for cols in genre_cols:
    train[cols] = train[cols] * train['rating']

# %%
train.head()
# Out:
#         userId  movieId  rating           timestamp  (no genres listed)  \
# 25794      177   112290     2.5 2015-07-02 02:35:34                 NaN
# 49800      318   127114     4.0 2015-11-18 18:24:36                 NaN
# 49156      318     2580     4.0 2012-01-06 17:53:15                 NaN
# 100240     610    52328     4.0 2016-11-19 07:54:45                 NaN
# 16435      105     5785     3.5 2015-11-06 01:27:03                 NaN
#
#         Action  Adventure  Animation  Children  Comedy  ...  Film-Noir  \
# 25794      NaN        NaN        NaN       NaN     NaN  ...        NaN
# 49800      NaN        NaN        NaN       NaN     NaN  ...        NaN
# 49156      NaN        NaN        NaN       NaN     4.0  ...        NaN
# 100240     NaN        4.0        NaN       NaN     NaN  ...        NaN
# 16435      3.5        NaN        NaN       NaN     3.5  ...        NaN
#
#         Horror  IMAX  Musical  Mystery  Romance  Sci-Fi  Thriller  War  \
# 25794      NaN   NaN      NaN      NaN      NaN     NaN       NaN  NaN
# 49800      NaN   NaN      NaN      NaN      NaN     NaN       NaN  NaN
# 49156      NaN   NaN      NaN      NaN      NaN     NaN       NaN  NaN
# 100240     NaN   NaN      NaN      NaN      NaN     4.0       4.0  NaN
# 16435      NaN   NaN      NaN      NaN      NaN     NaN       NaN  NaN
#
#         Western
# 25794       NaN
# 49800       NaN
# 49156       NaN
# 100240      NaN
# 16435       NaN
#
# [5 rows x 24 columns]

# %%
# 유저 별로 그룹을 만들어서 장르별 평균값 구하기
# 각 유저 별로 Action 아이템에 준 평점의 평균
train.groupby('userId')['Action'].mean()
# Out:
# userId
# 1       4.303797
# 2       4.125000
# 3       3.571429
# 4       3.428571
# 5       3.111111
#           ...
# 607     3.666667
# 608     3.338710
# 609     3.100000
# 610     3.607219
# 1000    5.000000
# Name: Action, Length: 611, dtype: float64

# %%
# 유저 프로필
user_profile = train.groupby('userId')[genre_cols].mean()
user_profile.sample()
# Out:
#         (no genres listed)  Action  Adventure  Animation  Children    Comedy  \
# userId
# 478                    NaN     3.0       2.75        3.0      3.25  2.714286
#
#         Crime  Documentary  Drama  Fantasy  Film-Noir  Horror  IMAX  Musical  \
# userId
# 478       3.5          NaN   2.25     3.25        NaN     0.5   4.5     3.75
#
#         Mystery  Romance  Sci-Fi  Thriller  War  Western
# userId
# 478         2.5      2.5     2.5     1.625  1.5      1.5

# %%
# 나의 유저 프로필 찾아보기
user_profile.loc[1000]
# Out:
# (no genres listed)    NaN
# Action                5.0
# Adventure             5.0
# Animation             NaN
# Children              NaN
# Comedy                NaN
# Crime                 NaN
# Documentary           NaN
# Drama                 5.0
# Fantasy               NaN
# Film-Noir             NaN
# Horror                NaN
# IMAX                  5.0
# Musical               NaN
# Mystery               NaN
# Romance               NaN
# Sci-Fi                5.0
# Thriller              5.0
# War                   NaN
# Western               NaN
# Name: 1000, dtype: float64

# %% [markdown]
# ## 샘플 유저의 평점 예측

# %%
# 테스트 데이터 중 인덱스 8313의 userId 가져와서 샘플 유저로 사용하기
sample = test.loc[8313]

# %%
# 57번 유저
sample_user = sample['userId']
sample_user
# Out:
# 57

# %%
# 57번 유저 프로필 가져오기
# 유저의 영화 성향을 알 수 있음
sample_user_profile = user_profile.loc[sample_user]
sample_user_profile
# Out:
# (no genres listed)         NaN
# Action                3.250000
# Adventure             3.430894
# Animation             3.866667
# Children              3.435897
# Comedy                3.407609
# Crime                 3.459016
# Documentary           4.000000
# Drama                 3.535484
# Fantasy               3.500000
# Film-Noir             4.090909
# Horror                2.769231
# IMAX                  3.750000
# Musical               3.840000
# Mystery               3.806452
# Romance               3.389474
# Sci-Fi                3.227848
# Thriller              3.150442
# War                   4.129032
# Western               3.625000
# Name: 57, dtype: float64

# %%
# Godzilla 영화에 대한 장르
print(sample['movieId'])
sample[genre_cols]
# Out:
# 1882
# (no genres listed)    NaN
# Action                1.0
# Adventure             NaN
# Animation             NaN
# Children              NaN
# Comedy                NaN
# Crime                 NaN
# Documentary           NaN
# Drama                 NaN
# Fantasy               NaN
# Film-Noir             NaN
# Horror                NaN
# IMAX                  NaN
# Musical               NaN
# Mystery               NaN
# Romance               NaN
# Sci-Fi                1.0
# Thriller              1.0
# War                   NaN
# Western               NaN
# Name: 8313, dtype: object

# %%
movies[movies['movieId'] == 1882]
# Out:
#       movieId            title                  genres
# 1373     1882  Godzilla (1998)  Action|Sci-Fi|Thriller

# %%
# 특정 영화인 Godzilla에 대한 57번 유저의 예상 평균 평점 구하기
sample_user_profile * sample[genre_cols]
# Out:
# (no genres listed)         NaN
# Action                    3.25
# Adventure                  NaN
# Animation                  NaN
# Children                   NaN
# Comedy                     NaN
# Crime                      NaN
# Documentary                NaN
# Drama                      NaN
# Fantasy                    NaN
# Film-Noir                  NaN
# Horror                     NaN
# IMAX                       NaN
# Musical                    NaN
# Mystery                    NaN
# Romance                    NaN
# Sci-Fi                3.227848
# Thriller              3.150442
# War                        NaN
# Western                    NaN
# dtype: object

# %%
# 57번 유저의 Godzilla 영화에 대한 예측된 평균 평점
(sample_user_profile * sample[genre_cols]).mean()
# Out:
# 3.2094301930473095

# %% [markdown]
# ## 전체 유저의 평점 예측

# %%
# 전체 데이터로 확장
for idx, row in test.iterrows():
    print(idx, row)
    break
# Out:
# 8313 userId                                 57
# movieId                              1882
# rating                                2.0
# timestamp             2000-08-09 05:30:10
# (no genres listed)                    NaN
# Action                                1.0
# Adventure                             NaN
# Animation                             NaN
# Children                              NaN
# Comedy                                NaN
# Crime                                 NaN
# Documentary                           NaN
# Drama                                 NaN
# Fantasy                               NaN
# Film-Noir                             NaN
# Horror                                NaN
# IMAX                                  NaN
# Musical                               NaN
# Mystery                               NaN
# Romance                               NaN
# Sci-Fi                                1.0
# Thriller                              1.0
# War                                   NaN
# Western                               NaN
# Name: 8313, dtype: object

# %%
# for문 진행 상황 확인
from tqdm import tqdm_notebook

# %%
predict = []
for idx, row in tqdm_notebook(test.iterrows()):
    # userId
    user = row['userId']
    # 유저 프로필 가져오기 * 아이템의 장르 정보
    predict.append((user_profile.loc[user] * row[genre_cols]).mean())
# Out:
# 0it [00:00, ?it/s]

# %%
test['predict'] = predict

# %%
test['predict']
# Out:
# 8313      3.209430
# 3424      3.229751
# 33637     4.052521
# 100232    3.665410
# 77733     3.786194
#             ...
# 39614     3.272912
# 49446     3.745655
# 48014     2.803571
# 44225     2.853662
# 64367     3.375285
# Name: predict, Length: 10084, dtype: float64

# %%
# Cold-Start 존재
test[test['predict'].isnull()]
# Out:
#        userId  movieId  rating           timestamp  (no genres listed)  \
# 36355     248   122896     4.0 2018-08-18 11:34:18                 1.0
# 36369     248   171011     3.5 2018-08-22 15:15:54                 NaN
# 76223     479     5643     3.0 2002-12-08 17:11:09                 NaN
# 60265     388     1203     1.0 2013-12-10 16:48:52                 NaN
# 72418     467     2394     2.0 1999-02-22 08:02:39                 NaN
# 48086     312     1289     5.0 2003-01-21 19:26:40                 NaN
# 14881      95      162     5.0 2003-01-23 16:45:11                 NaN
# 96017     602      246     3.0 1996-08-24 08:43:48                 NaN
# 3624       21   122896     4.0 2016-01-06 03:49:23                 1.0
# 22163     147      596     3.0 2008-02-17 17:02:10                 NaN
# 15004      95     5619     4.0 2003-01-23 16:28:22                 NaN
# 90029     585     5325     4.5 2011-06-07 03:36:04                 NaN
# 85306     555      116     3.0 2001-01-22 00:55:22                 NaN
# 90486     589      246     5.0 1997-02-15 21:48:24                 NaN
# 60384     390     8622     4.5 2009-08-15 13:17:38                 NaN
# 60393     390    44943     5.0 2009-08-15 11:34:37                 NaN
#
#        Action  Adventure  Animation  Children  Comedy  ...  Horror  IMAX  \
# 36355     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 36369     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 76223     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 60265     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 72418     NaN        NaN        1.0       NaN     NaN  ...     NaN   NaN
# 48086     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 14881     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 96017     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 3624      NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 22163     NaN        NaN        1.0       1.0     NaN  ...     NaN   NaN
# 15004     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 90029     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 85306     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 90486     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 60384     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
# 60393     NaN        NaN        NaN       NaN     NaN  ...     NaN   NaN
#
#        Musical  Mystery  Romance  Sci-Fi  Thriller  War  Western  predict
# 36355      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 36369      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 76223      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 60265      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 72418      1.0      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 48086      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 14881      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 96017      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 3624       NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 22163      1.0      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 15004      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 90029      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 85306      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 90486      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 60384      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
# 60393      NaN      NaN      NaN     NaN       NaN  NaN      NaN      NaN
#
# [16 rows x 25 columns]

# %%
# Cold Start 문제로 인한 NaN은 global mean으로 넣어주기
test.loc[test['predict'].isnull(), 'predict'] = train['rating'].mean()

# %%
test[test['predict'].isnull()]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp, (no genres listed), Action, Adventure, Animation, Children, Comedy, Crime, Documentary, Drama, Fantasy, Film-Noir, Horror, IMAX, Musical, Mystery, Romance, Sci-Fi, Thriller, War, Western, predict]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ## 모델 평가

# %%
# rsme로 평가
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(test['rating'], test['predict'])
rmse = np.sqrt(mse)
rmse
# Out:
# 0.9078973553755864
